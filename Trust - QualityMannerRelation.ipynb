# %%
import pandas as pd
import gensim
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec, Doc2Vec
from nltk.tokenize import word_tokenize
import nltk

from sklearn.metrics.pairwise import cosine_similarity
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import torch
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification

fallacy_model = AutoModelForSequenceClassification.from_pretrained("q3fer/distilbert-base-fallacy-classification")
tokenizer = AutoTokenizer.from_pretrained("q3fer/distilbert-base-fallacy-classification")


def get_fallacy_score(text):
    inputs = tokenizer(text, return_tensors='pt')

    with torch.no_grad():
      logits = fallacy_model(**inputs)
      scores = logits[0][0]
      scores = torch.nn.Softmax(dim=0)(scores)

      _, ranking = torch.topk(scores, k=scores.shape[0])
      ranking = ranking.tolist()
    
    
    if float(max(scores)) < 0.5:
        return 0
    else: 
        score = (float(max(scores)) - 0.5) / 0.5
    return score

# %%
def sentence_vector(sentence, model):
    words = word_tokenize(sentence.lower())
    vectors = [model.wv[word] for word in words if word in model.wv] #vectors of words

    if vectors: #sentence vector ==> average of words vectors of that sentence
        return sum(vectors) / len(vectors)
    else:
        return None
    
def calculate_cosine_similarity(vec1, vec2):
    return cosine_similarity(vec1.reshape(1, -1), vec2.reshape(1, -1))[0][0]

def perform_sentiment_analysis(text):
    sia = SentimentIntensityAnalyzer()
    sentiment_scores = sia.polarity_scores(text)
    return sentiment_scores

def normalize(list_):
    return [(e+1)/2 for e in list_]

# %%
df = pd.read_csv('QA.csv')
df.dropna(inplace=True)
corpus = list(df['instruction']) + list(df['response'])
tokenized = [simple_preprocess(sentence) for sentence in corpus]

# %%
model = Word2Vec(sentences=tokenized, vector_size=100, window=5, min_count=1, workers=4)

# %%
vectorized = [sentence_vector(sentence, model) for sentence in corpus]

# %%
len(vectorized[0])
# Out:
# 8

# %%
corpus[0]
# Out:
# 'Why can camels survive for long without water?'

# %%
questions = vectorized[:int(len(vectorized)/2)]
answers = vectorized[int(len(vectorized)/2):]
corpus_a = corpus[int(len(corpus)/2):]

# %%
for i in range(len(answers)-1, 0, -1):
    if answers[i] is None:
        del answers[i]
        del questions[i]
        del corpus_a[i]
        df = df.drop(i)
df.reset_index(inplace=True, drop=True)

# %%
sim = []
sent = []
fall = []

for q, a, a_og in zip(questions, answers, corpus_a):
    s = calculate_cosine_similarity(q, a)
    sim.append(s)
    
    st = perform_sentiment_analysis(a_og)
    sent.append(st['compound'])
    
    try:
        f = get_fallacy_score(a_og)
    except:
        f = 999
    fall.append(1-f)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (517 > 512). Running this sequence through the model will result in indexing errors

# %%
df['Relation'] = normalize(sim)
df['Manner'] = normalize(sent)
df['Quality'] = fall
df
# Out:
#                                             instruction  \
# 0        Why can camels survive for long without water?
# 1     Alice's parents have three daughters: Amy, Jes...
# 2      Who gave the UN the land in NY to build their HQ
# 3                                    What is a polygon?
# 4     Which episodes of season four of Game of Thron...
# ...                                                 ...
# 3699          What does troll the respawn, Jeremy mean?
# 3700      Who won the World Chess Championship in 2021?
# 3701           Why is it a good idea to walk every day?
# 3702                      Who is the creator of Python?
# 3703  What is the difference between a road bike and...
#
#                                                response  Relation   Manner  \
# 0     Camels use the fat in their humps to keep them...  0.991368  0.63660
# 1               The name of the third daughter is Alice  0.996900  0.50000
# 2                                   John D Rockerfeller  0.998289  0.50000
# 3     A polygon is a form in Geometry.  It is a sing...  0.995580  0.53860
# 4     She directed "Oathkeeper" and "First of His Na...  0.999511  0.67000
# ...                                                 ...       ...      ...
# 3699  Trolling the respawn refers to when in video g...  0.996649  0.16475
# 3700  Magnus Carlsen defeated Ian Nepomniachtchi 7.5...  0.995049  0.60115
# 3701  Walking is a good exercise for burning calorie...  0.999820  0.94070
# 3702  Guido van Rossum is the father of Python. And ...  0.999793  0.50000
# 3703  Road bikes are built to be ridden on asphalt a...  0.985763  0.47510
#
#        Quality
# 0     1.000000
# 1     0.608241
# 2     1.000000
# 3     0.524350
# 4     0.988467
# ...        ...
# 3699  0.734557
# 3700  1.000000
# 3701  1.000000
# 3702  0.423567
# 3703  0.119512
#
# [3704 rows x 5 columns]

# %%
df[df['Relation'] < 0.5]
#Single-words responses are more or less seen as neutral
# Out:
#                                             instruction      response  \
# 13             Who saved Andromeda from the sea monster       Perseus
# 103   What dog breed is a mix between a Cocker Spani...      Cockapoo
# 224           What is Bart Simpson's best friend named?     Millhouse
# 359   What kind of dog breed do you get when you mat...  sheepadoodle
# 360                Which country is alphabetically last      Zimbabwe
# 565   What are the India’s Foreign Exchange Reserves...    $545.65 bn
# 613                 Kaka means parrot in which language         Maori
# 881      Which African country was founded by Americans       Liberia
# 1258  Marburg Virus Disease belongs to the same fami...         Ebola
# 1270    Which author wrote the ‘Winnie-the-Pooh’ books?   A. A. Milne
# 1422  What is the east Asian process of training sma...        Bonsai
# 1489                   Where is Babylon remain located?          Irag
# 1978  what is the name of the podcast hosted by luke...          TBTL
# 1983         What is Apu's wife's name on the Simpsons?       Manjula
# 2214  In 93rd Academy Awards(Oscar Awards)The Best P...     Nomadland
# 2526  As a child, what singer held the longest note ...         Usher
# 2558              Who was among the famous Roman poets?        Virgil
# 2921     To which London club did Mycroft Holmes belong      Diogones
# 3168          Pupik means belly button in what language       Yiddish
# 3320  Queen Elizabeth II, who reigned UK for 70 year...      Balmoral
# 3392  Which German word means lightning war used in WW2    Blitzkrieg
#
#       Relation  Manner   Quality
# 13    0.396460     0.5  1.000000
# 103   0.490490     0.5  1.000000
# 224   0.456857     0.5  0.952592
# 359   0.465489     0.5  1.000000
# 360   0.475220     0.5  0.994472
# 565   0.490747     0.5  0.496157
# 613   0.429675     0.5  1.000000
# 881   0.438918     0.5  1.000000
# 1258  0.405654     0.5  0.794926
# 1270  0.429594     0.5  1.000000
# 1422  0.464936     0.5  0.798140
# 1489  0.485978     0.5  1.000000
# 1978  0.477214     0.5  1.000000
# 1983  0.488137     0.5  1.000000
# 2214  0.464475     0.5  1.000000
# 2526  0.457682     0.5  1.000000
# 2558  0.460997     0.5  1.000000
# 2921  0.463670     0.5  1.000000
# 3168  0.474909     0.5  0.563645
# 3320  0.488823     0.5  1.000000
# 3392  0.465856     0.5  1.000000

# %%
df[df['Quality']==-998]
#responses are too long and it crashed!
# Out:
#                                             instruction  \
# 67                                  What is the FA Cup?
# 1232  What is the successor liability and can you gi...
# 1531  What are the key steps for building a an in gr...
# 1533                           What is genome analysis?
# 1968            Name some famous poets and their poems.
# 2127           What is the plot of the movie John Wick?
# 2136            Who is the greatest artist of all time?
# 2537  What is the history of the Masters Golf Tourna...
# 2647                           What is a mitochondrion?
# 3023  What are the advantages and disadvantages of l...
# 3054  What planning should you do to visit Walt Disn...
# 3308  What is the nuclear magnetic resonance spectro...
# 3503  What is the list of football clubs in England ...
# 3509  Name all of the NBA Championship teams in hist...
# 3605                              What is glass made of
# 3674                       What is structural genomics?
#
#                                                response  Relation   Manner  \
# 67    The Football Association Challenge Cup, more c...  0.997826  0.99355
# 1232  In law, successor liability is liability (debt...  0.997938  0.35975
# 1531  Pre-construction site meeting - Before startin...  0.996525  0.98090
# 1533  The genome sequence of an organism includes th...  0.996873  0.78950
# 1968  Edgar Allen Poe\nBirthplace: Boston\nFamous po...  0.999073  0.99955
# 2127  John Wick is grieving the death of his wife, H...  0.991997  0.00120
# 2136  Michael Jackson\nMichael Jackson (Michael Jose...  0.997590  0.99685
# 2537  The Masters was started by amateur champion Bo...  0.994003  0.99870
# 2647  A mitochondrion is an organelle found in the c...  0.994363  0.92870
# 3023  Java and Python are two of the most popular pr...  0.992072  0.99970
# 3054  You should start planning your Walt Disney Wor...  0.995659  0.99665
# 3308  Nuclear magnetic resonance spectroscopy of pro...  0.991494  0.98615
# 3503  This article lists English association footbal...  0.998975  0.99975
# 3509  2021-22 | Finals: Golden State Warriors def. B...  0.991697  0.72020
# 3605  Glass has become so commonplace today that it’...  0.989531  0.98570
# 3674  Structural genomics seeks to describe the 3-di...  0.996860  0.98715
#
#       Quality
# 67     -998.0
# 1232   -998.0
# 1531   -998.0
# 1533   -998.0
# 1968   -998.0
# 2127   -998.0
# 2136   -998.0
# 2537   -998.0
# 2647   -998.0
# 3023   -998.0
# 3054   -998.0
# 3308   -998.0
# 3503   -998.0
# 3509   -998.0
# 3605   -998.0
# 3674   -998.0

# %%
print ("Responses without fallacies:", len(df[df['Quality']==1]))
print ("Responses with fallacies:", len(df[(df['Quality']!=1) & (df['Quality']!=-998)]))
# Out:
# Responses without fallacies: 1820
# Responses with fallacies: 1868

# %%
df[(df['Quality']!=1) & (df['Quality']!=-998)].sort_values(by=['Quality'])[:10]
# Out:
#                                             instruction  \
# 2447      What coloring of cat is almost always female?
# 2809  Why are dogs better than cats for a person's p...
# 1318  What's the easiest way to make friends when tr...
# 159   What family do tigers, lions and panthers all ...
# 1220       International Booker Prize 2021 was given to
# 1700           Pultizer Prize 2022 is given which field
# 3092        What coloring of cat is almost always male?
# 1768          Do Harry Potter and Hermione get married?
# 701   Why is the World Cup the best sporting competi...
# 2378                            How do you ride a bike?
#
#                                                response  Relation   Manner  \
# 2447              Calico cats are almost always female.  0.986115  0.50000
# 2809  Dogs keep their owners more active by needing ...  0.999736  0.86580
# 1318  Traveling alone to anywhere in the world can b...  0.997967  0.99825
# 159   Tigers, lions and panthers are all a part of t...  0.990352  0.50000
# 1220                        At night all blood is black  0.998662  0.50000
# 1700                 Journalism, Books, Drama and Music  0.998981  0.50000
# 3092                    Orange cats are generally male.  0.986280  0.50000
# 1768  No. Hermione Granger ends up marrying Ron Weas...  0.995478  0.50000
# 701   The World Cup is a global event that happens o...  0.997173  0.84040
# 2378  You can learn to ride a bike by starting with ...  0.985265  0.91125
#
#        Quality
# 2447  0.023710
# 2809  0.033793
# 1318  0.034160
# 159   0.038841
# 1220  0.040264
# 1700  0.041935
# 3092  0.042171
# 1768  0.043267
# 701   0.046340
# 2378  0.048590

# %%
# sent2vec
# rivedere modelli
#

# %% [markdown]
# # Experiments with NER

# %%
a, b, c, d, e, f = str("a"), str("b"), str("c"), str("d"), str("e"), str("f")
g, h, i = 1, 1, 1

# %%
words = [a, b, c, d, e, f]
stops = [g, h, i]
NER = [a, f]

#weight = len(words) / len(NER) #NO! Se non ci sono NER è impossibile
boost1 = 1 - (len(NER) / len(words))
boost2 = (len(NER) / len(words))

# %%
#boost normale
real_w = 0
stop_w = len(stops)

for word in words:
    if word in NER:
        real_w += 1 + boost1
    else:
        real_w += 1

real_w / (real_w + stop_w)
# Out:
# 0.7096774193548387

# %%
#boost ???
real_w = 0
stop_w = len(stops)

for word in words:
    if word in NER:
        real_w += 1 + boost2
    else:
        real_w += 1

real_w / (real_w + stop_w)
# Out:
# 0.689655172413793
